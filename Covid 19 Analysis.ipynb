# %%
# Importing libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_json('https://www.mohfw.gov.in/data/datanew.json')
# Reading dataset

# %% [markdown]
# ### This above cell was last run on 12-01-2021, The dataset below is as of 12-01-2021.

# %%
df
# Loading dataset
# Out:
#     sno                                state_name  active  positive     cured  \
# 0     1               Andaman and Nicobar Islands      34     10490     10327
# 1     2                            Andhra Pradesh    1630   2333672   2317309
# 2     3                         Arunachal Pradesh     322     66205     65587
# 3     4                                     Assam    4426    741502    729054
# 4     5                                     Bihar    1014    844858    831559
# 5     6                                Chandigarh     769     97370     95430
# 6     7                              Chhattisgarh    3341   1169143   1151722
# 7     8  Dadra and Nagar Haveli and Daman and Diu      26     11556     11526
# 8     9                                     Delhi    8045   1969527   1935152
# 9    10                                      Goa*    1011    253042    248176
# 10   11                                   Gujarat    5895   1261261   1244388
# 11   12                                   Haryana    4685   1035974   1020641
# 12   13                          Himachal Pradesh    5070    304629    295385
# 13   14                         Jammu and Kashmir    5304    469749    459669
# 14   15                                 Jharkhand     897    440925    434700
# 15   16                                 Karnataka   11898   4020087   3968029
# 16   17                                 Kerala***   10656   6729855   6648627
# 17   18                                    Ladakh     113     29004     28663
# 18   19                               Lakshadweep       0     11415     11363
# 19   20                            Madhya Pradesh    1355   1051278   1039161
# 20   21                               Maharashtra   12011   8059732   7899582
# 21   22                                   Manipur     255    139348    136955
# 22   23                                 Meghalaya     706     95909     93592
# 23   24                                   Mizoram    1239    234144    232194
# 24   25                                  Nagaland      62     35835     35001
# 25   26                                    Odisha    5904   1318875   1303823
# 26   27                                Puducherry     701    171628    168960
# 27   28                                  Punjab**   12155    777086    747101
# 28   29                                 Rajasthan    3438   1297262   1284234
# 29   30                                    Sikkim     568     42767     41725
# 30   31                                Tamil Nadu    9889   3552698   3504776
# 31   32                                 Telangana    5910    825756    815735
# 32   33                                   Tripura     753    107344    105656
# 33   34                               Uttarakhand    2584    444963    434661
# 34   35                             Uttar Pradesh    4997   2107954   2079382
# 35   36                               West Bengal    7847   2099056   2069814
# 36   37                                            135510  44161899  43499659
#
#      death  new_active  new_positive  new_cured  new_death death_reconsille  \
# 0      129          40         10502      10333        129
# 1    14733        1453       2333710    2317524      14733
# 2      296         295         66246      65655        296
# 3     8022        4006        741541     729513       8022
# 4    12285        1024        844997     831688      12285
# 5     1171         772         97442      95499       1171
# 6    14080        3282       1169532    1152169      14081
# 7        4          23         11557      11530          4
# 8    26330        7484       1970899    1937079      26336
# 9     3855        1046        253162     248261       3855
# 10   10978        5862       1261922    1245080      10980
# 11   10648        4598       1036795    1021547      10650
# 12    4174        4919        305383     296287       4177
# 13    4776        5045        470201     460380       4776
# 14    5328         837        441010     434845       5328
# 15   40160       11252       4021106    3969691      40163
# 16   70582       10179       6730762    6650001      70582               10
# 17     228         118         29021      28675        228
# 18      52           0         11415      11363         52
# 19   10762        1349       1051447    1039336      10762
# 20  148139       11968       8060737    7900626     148143
# 21    2138         244        139377     136995       2138
# 22    1611         686         95925      93628       1611
# 23     711        1214        234387     232461        712
# 24     772          54         35838      35012        772
# 25    9148        5851       1319527    1304527       9149
# 26    1967         640        171651     169044       1967
# 27   17830       12429        777362     747101      17832
# 28    9590        3813       1297814    1284411       9590
# 29     474         476         42784      41834        474
# 30   38033        9408       3553670    3506229      38033
# 31    4111        5667        826284     816506       4111
# 32     935         653        107419     105831        935
# 33    7718        2378        445106     435009       7719
# 34   23575        5440       2108686    2079670      23576
# 35   21395        7302       2099433    2070731      21400
# 36  526740      131807      44174650   43516071     526772               10
#
#    total  state_code  actualdeath24hrs
# 0                 35                 0
# 1                 28                 0
# 2                 12                 0
# 3                 18                 0
# 4                 10                 0
# 5                  4                 0
# 6      1          22                 1
# 7                 26                 0
# 8      6           7                 6
# 9                 30                 0
# 10     2          24                 2
# 11     2           6                 2
# 12     3           2                 3
# 13                 1                 0
# 14                20                 0
# 15     3          29                 3
# 16    10          32                 0
# 17                37                 0
# 18                31                 0
# 19                23                 0
# 20     4          27                 4
# 21                14                 0
# 22                17                 0
# 23     1          15                 1
# 24                13                 0
# 25     1          21                 1
# 26                34                 0
# 27     2           3                 2
# 28                 8                 0
# 29                11                 0
# 30                33                 0
# 31                36                 0
# 32                16                 0
# 33     1           5                 1
# 34     1           9                 1
# 35     5          19                 5
# 36    42           0                32

# %% [markdown]
# ### DataUnderstanding

# %%
df.shape
# There are 37 rows and 11 columns
# Out:
# (37, 14)

# %%
df.isnull().sum()
# no null values
# Out:
# sno                 0
# state_name          0
# active              0
# positive            0
# cured               0
# death               0
# new_active          0
# new_positive        0
# new_cured           0
# new_death           0
# death_reconsille    0
# total               0
# state_code          0
# actualdeath24hrs    0
# dtype: int64

# %%
df.info()
# type of data present in the columns(int,object)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sno               37 non-null     int64
#  1   state_name        37 non-null     object
#  2   active            37 non-null     int64
#  3   positive          37 non-null     int64
#  4   cured             37 non-null     int64
#  5   death             37 non-null     int64
#  6   new_active        37 non-null     int64
#  7   new_positive      37 non-null     int64
#  8   new_cured         37 non-null     int64
#  9   new_death         37 non-null     int64
#  10  death_reconsille  37 non-null     object
#  11  total             37 non-null     object
#  12  state_code        37 non-null     int64
#  13  actualdeath24hrs  37 non-null     int64
# dtypes: int64(11), object(3)
# memory usage: 4.2+ KB

# %%
df.describe()
# Viewing the descriptive statistics of the data like mean, std deviation, min and max values present in the dataset
# Out:
#              sno         active      positive         cured          death  \
# count  37.000000      37.000000  3.700000e+01  3.700000e+01      37.000000
# mean   19.000000    7324.864865  2.387130e+06  2.351333e+06   28472.432432
# std    10.824355   21994.360622  7.281370e+06  7.171866e+06   88317.856831
# min     1.000000       0.000000  1.049000e+04  1.032700e+04       4.000000
# 25%    10.000000     706.000000  1.073440e+05  1.056560e+05    1171.000000
# 50%    19.000000    2584.000000  7.415020e+05  7.290540e+05    7718.000000
# 75%    28.000000    5904.000000  1.318875e+06  1.303823e+06   14733.000000
# max    37.000000  135510.000000  4.416190e+07  4.349966e+07  526740.000000
#
#           new_active  new_positive     new_cured      new_death  state_code  \
# count      37.000000  3.700000e+01  3.700000e+01      37.000000   37.000000
# mean     7124.702703  2.387819e+06  2.352220e+06   28474.162162   18.324324
# std     21395.312638  7.283409e+06  7.174493e+06   88322.938900   11.212726
# min         0.000000  1.050200e+04  1.033300e+04       4.000000    0.000000
# 25%       653.000000  1.074190e+05  1.058310e+05    1171.000000    9.000000
# 50%      2378.000000  7.415410e+05  7.295130e+05    7719.000000   18.000000
# 75%      5851.000000  1.319527e+06  1.304527e+06   14733.000000   28.000000
# max    131807.000000  4.417465e+07  4.351607e+07  526772.000000   37.000000
#
#        actualdeath24hrs
# count         37.000000
# mean           1.729730
# std            5.336711
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            1.000000
# max           32.000000

# %%
df.keys()
# Displaying all the column names present in data
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code', 'actualdeath24hrs'],
#       dtype='object')

# %%
df.columns
# Different code but same purpose as above that is displaying all column names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code', 'actualdeath24hrs'],
#       dtype='object')

# %%
df.nunique()
# The nunique() function is used to count distinct observations over requested axis. It returns Series with number of distinct observations.
# Out:
# sno                 37
# state_name          37
# active              37
# positive            37
# cured               37
# death               37
# new_active          37
# new_positive        37
# new_cured           37
# new_death           37
# death_reconsille     2
# total                9
# state_code          37
# actualdeath24hrs     8
# dtype: int64

# %%
df.tail()
# As we can see there is an extra row in the end that may be the total of that column
# Out:
#     sno     state_name  active  positive     cured   death  new_active  \
# 32   33        Tripura     753    107344    105656     935         653
# 33   34    Uttarakhand    2584    444963    434661    7718        2378
# 34   35  Uttar Pradesh    4997   2107954   2079382   23575        5440
# 35   36    West Bengal    7847   2099056   2069814   21395        7302
# 36   37                 135510  44161899  43499659  526740      131807
#
#     new_positive  new_cured  new_death death_reconsille total  state_code  \
# 32        107419     105831        935                                 16
# 33        445106     435009       7719                      1           5
# 34       2108686    2079670      23576                      1           9
# 35       2099433    2070731      21400                      5          19
# 36      44174650   43516071     526772               10    42           0
#
#     actualdeath24hrs
# 32                 0
# 33                 1
# 34                 1
# 35                 5
# 36                32

# %%
df=df.iloc[:36]
# we apply the iloc function and select all rows except the last row

# %%
df
# This is the dataset that we are to work on
# Out:
#     sno                                state_name  active  positive    cured  \
# 0     1               Andaman and Nicobar Islands      34     10490    10327
# 1     2                            Andhra Pradesh    1630   2333672  2317309
# 2     3                         Arunachal Pradesh     322     66205    65587
# 3     4                                     Assam    4426    741502   729054
# 4     5                                     Bihar    1014    844858   831559
# 5     6                                Chandigarh     769     97370    95430
# 6     7                              Chhattisgarh    3341   1169143  1151722
# 7     8  Dadra and Nagar Haveli and Daman and Diu      26     11556    11526
# 8     9                                     Delhi    8045   1969527  1935152
# 9    10                                      Goa*    1011    253042   248176
# 10   11                                   Gujarat    5895   1261261  1244388
# 11   12                                   Haryana    4685   1035974  1020641
# 12   13                          Himachal Pradesh    5070    304629   295385
# 13   14                         Jammu and Kashmir    5304    469749   459669
# 14   15                                 Jharkhand     897    440925   434700
# 15   16                                 Karnataka   11898   4020087  3968029
# 16   17                                 Kerala***   10656   6729855  6648627
# 17   18                                    Ladakh     113     29004    28663
# 18   19                               Lakshadweep       0     11415    11363
# 19   20                            Madhya Pradesh    1355   1051278  1039161
# 20   21                               Maharashtra   12011   8059732  7899582
# 21   22                                   Manipur     255    139348   136955
# 22   23                                 Meghalaya     706     95909    93592
# 23   24                                   Mizoram    1239    234144   232194
# 24   25                                  Nagaland      62     35835    35001
# 25   26                                    Odisha    5904   1318875  1303823
# 26   27                                Puducherry     701    171628   168960
# 27   28                                  Punjab**   12155    777086   747101
# 28   29                                 Rajasthan    3438   1297262  1284234
# 29   30                                    Sikkim     568     42767    41725
# 30   31                                Tamil Nadu    9889   3552698  3504776
# 31   32                                 Telangana    5910    825756   815735
# 32   33                                   Tripura     753    107344   105656
# 33   34                               Uttarakhand    2584    444963   434661
# 34   35                             Uttar Pradesh    4997   2107954  2079382
# 35   36                               West Bengal    7847   2099056  2069814
#
#      death  new_active  new_positive  new_cured  new_death death_reconsille  \
# 0      129          40         10502      10333        129
# 1    14733        1453       2333710    2317524      14733
# 2      296         295         66246      65655        296
# 3     8022        4006        741541     729513       8022
# 4    12285        1024        844997     831688      12285
# 5     1171         772         97442      95499       1171
# 6    14080        3282       1169532    1152169      14081
# 7        4          23         11557      11530          4
# 8    26330        7484       1970899    1937079      26336
# 9     3855        1046        253162     248261       3855
# 10   10978        5862       1261922    1245080      10980
# 11   10648        4598       1036795    1021547      10650
# 12    4174        4919        305383     296287       4177
# 13    4776        5045        470201     460380       4776
# 14    5328         837        441010     434845       5328
# 15   40160       11252       4021106    3969691      40163
# 16   70582       10179       6730762    6650001      70582               10
# 17     228         118         29021      28675        228
# 18      52           0         11415      11363         52
# 19   10762        1349       1051447    1039336      10762
# 20  148139       11968       8060737    7900626     148143
# 21    2138         244        139377     136995       2138
# 22    1611         686         95925      93628       1611
# 23     711        1214        234387     232461        712
# 24     772          54         35838      35012        772
# 25    9148        5851       1319527    1304527       9149
# 26    1967         640        171651     169044       1967
# 27   17830       12429        777362     747101      17832
# 28    9590        3813       1297814    1284411       9590
# 29     474         476         42784      41834        474
# 30   38033        9408       3553670    3506229      38033
# 31    4111        5667        826284     816506       4111
# 32     935         653        107419     105831        935
# 33    7718        2378        445106     435009       7719
# 34   23575        5440       2108686    2079670      23576
# 35   21395        7302       2099433    2070731      21400
#
#    total  state_code  actualdeath24hrs
# 0                 35                 0
# 1                 28                 0
# 2                 12                 0
# 3                 18                 0
# 4                 10                 0
# 5                  4                 0
# 6      1          22                 1
# 7                 26                 0
# 8      6           7                 6
# 9                 30                 0
# 10     2          24                 2
# 11     2           6                 2
# 12     3           2                 3
# 13                 1                 0
# 14                20                 0
# 15     3          29                 3
# 16    10          32                 0
# 17                37                 0
# 18                31                 0
# 19                23                 0
# 20     4          27                 4
# 21                14                 0
# 22                17                 0
# 23     1          15                 1
# 24                13                 0
# 25     1          21                 1
# 26                34                 0
# 27     2           3                 2
# 28                 8                 0
# 29                11                 0
# 30                33                 0
# 31                36                 0
# 32                16                 0
# 33     1           5                 1
# 34     1           9                 1
# 35     5          19                 5

# %%
df['active'].sum(axis = 0) 
# The total number of active cases in India is 2,22,526
# Out:
# 135510

# %%
df['positive'].sum(axis = 0) 
# The total number of positive cases in India are 10,466,595
# Out:
# 44161899

# %%
df['cured'].sum(axis = 0)
# The total number of cured cases in India is 10,092,909
# Out:
# 43499659

# %%
df['death'].sum(axis = 0)
# The total number of deaths in India are 1,51,160
# Out:
# 526740

# %%
df['new_active'].sum(axis = 0)
# The total number of new active cases are 2,16,558
# Out:
# 131807

# %%
df['new_positive'].sum(axis = 0)
# The total number of new positive cases are 10,479,179
# Out:
# 44174650

# %%
df['new_cured'].sum(axis = 0)
# The total number of new cured cases are 10,111,294
# Out:
# 43516071

# %%
df['new_death'].sum(axis = 0)
# The total number of new death cases are 1,51,327
# Out:
# 526772

# %% [markdown]
# ### Data Visualization

# %%
sns.pairplot(data=df)
# plotting scatter plots of all data using pairplot

# %%
cases_df=df.sum()
# Storing total cases in cases_df

# %%
cases_df
# Subset of original dataset
# Out:
# sno                                                               666
# state_name          Andaman and Nicobar IslandsAndhra PradeshAruna...
# active                                                         135510
# positive                                                     44161899
# cured                                                        43499659
# death                                                          526740
# new_active                                                     131807
# new_positive                                                 44174650
# new_cured                                                    43516071
# new_death                                                      526772
# death_reconsille                                                   10
# total                                                 162233104112115
# state_code                                                        678
# actualdeath24hrs                                                   32
# dtype: object

# %%
cases_df.drop(['sno','state_name','state_code'],inplace=True)
# Dropping unnecessary columns

# %%
cases_df
# Name of case types and their total number
# Out:
# active                       135510
# positive                   44161899
# cured                      43499659
# death                        526740
# new_active                   131807
# new_positive               44174650
# new_cured                  43516071
# new_death                    526772
# death_reconsille                 10
# total               162233104112115
# actualdeath24hrs                 32
# dtype: object

# %%
my_data = [222526,10466595,10092909,151160]
my_labels = 'Active','Positive','Cured','Death'
my_explode = (0,0,0,1.5)
my_colors = ['lightblue','lightsteelblue','lightpink','black']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
my_data = [216558,10479179,10111294,151327]
my_labels = 'New Active','New Positive','New Cured','New Death'
my_explode = (0,0,0,1.5)
my_colors = ['lightblue','lightsteelblue','lightpink','black']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
my_data = [222526,10466595,10092909,151160,216558,10479179,10111294,151327]
my_labels = 'Active','Positive','Cured','Death','New Active','New Positive','New Cured','New Death'
my_explode = (0,0,0,0,0,0,0,1.5)
my_colors = ['gray','navajowhite','blanchedalmond','grey','lightblue','papayawhip','moccasin','lightpink']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
plt.rcParams['figure.figsize']=(13,8)
# giving figure size

# %%
df[['state_name','active']].groupby(["state_name"]).mean().sort_values(by='active').plot.bar(color='purple')
plt.show()
# We can also use the groupby function to sort values in an ascending order based on the x-axis, y-axis and its keys
# Below we get a clear picture of the states in an increasing order based on their active level of cases.
# Kerela has a higher active cases compared to other states

# %%
df[['state_name','death']].groupby(["state_name"]).mean().sort_values(by='death').plot.bar(color='purple')
plt.show()
# We can also use the groupby function to sort values in an ascending order based on the x-axis, y-axis and its keys
# Below we get a clear picture of the states in an increasing order based on their death cases.
# Maharashtra has a higher death cases compared to other states

# %%
df.columns
# Displaying column names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code', 'actualdeath24hrs'],
#       dtype='object')

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='active',color='teal',data=df);
# The visualization below shows us that high number of active cases are found in kerala followed by maharashtra

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='positive',color='teal',data=df);
# The below visualization shows us that high number of positive cases can be seen in Maharashtra followed by karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='cured',color='teal',data=df);
# The visualization below shows us that high number of people have cured in the state of Maharashtra followed by karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='death',color='teal',data=df);
# The below visualization shows us that high number of deaths taking place in the state of Maharashtra followed by Tamilnadu and karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_active',color='teal',data=df);
# The following visualization shows us the total number of new cases and kerela has the high number of new active cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_positive',color='teal',data=df);
# The following visualization shows us the total number of new positive cases and Maharashtra has the high number of new positive cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_cured',color='teal',data=df);
# The following visualization shows us the total number of new cured cases and Maharashtra has the high number of new cured cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_death',color='teal',data=df);
# Maharashtra has the highest new death rates in India followed by Karnataka

# %%
df.columns
# column names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code', 'actualdeath24hrs'],
#       dtype='object')

# %%
df.drop(['sno','state_code'],axis=1,inplace=True)
# we have dropped columns like sno and statecode
# Out:
# C:\Users\rosha\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.head(5)
# This is the resulting data
# Out:
#                     state_name  active  positive   cured  death  new_active  \
# 0  Andaman and Nicobar Islands      23      4960    4875     62          17
# 1               Andhra Pradesh    2544    884916  875243   7129        2450
# 2            Arunachal Pradesh      66     16772   16650     56          63
# 3                        Assam    3014    216590  212515   1061        2992
# 4                        Bihar    4178    255700  250088   1434        4054
#
#    new_positive  new_cured  new_death
# 0          4963       4884         62
# 1        885037     875456       7131
# 2         16777      16658         56
# 3        216635     212579       1064
# 4        255932     250439       1439

# %%
df=df.set_index('state_name')
# Setting index as statename

# %%
df.head(5)
# Out:
#                              active  positive    cured  death  new_active  \
# state_name
# Andaman and Nicobar Islands      34     10490    10327    129          40
# Andhra Pradesh                 1630   2333672  2317309  14733        1453
# Arunachal Pradesh               322     66205    65587    296         295
# Assam                          4426    741502   729054   8022        4006
# Bihar                          1014    844858   831559  12285        1024
#
#                              new_positive  new_cured  new_death  \
# state_name
# Andaman and Nicobar Islands         10502      10333        129
# Andhra Pradesh                    2333710    2317524      14733
# Arunachal Pradesh                   66246      65655        296
# Assam                              741541     729513       8022
# Bihar                              844997     831688      12285
#
#                             death_reconsille total  actualdeath24hrs
# state_name
# Andaman and Nicobar Islands                                        0
# Andhra Pradesh                                                     0
# Arunachal Pradesh                                                  0
# Assam                                                              0
# Bihar                                                              0

# %%
df.plot.barh(stacked=True,figsize=(13,8))
# Stacked bar plot
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
df1=df[['cured', 'death']] 
df1.plot.barh(color={"cured": "purple", "death": "black"},figsize=(13,8))
# bar plot for cured and death
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
df2=df[['positive', 'death']] 
df2.plot.barh(color={"positive": "aquamarine", "death": "orange"},figsize=(13,8))
# bar plot for positive cases and death rate
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
df3=df[['death', 'cured']] 
df3.plot.barh(color={"death": "red", "cured": "grey"},figsize=(13,8))
# barplot for death cases and cured cases
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
df4=df[['active', 'death']] 
df4.plot.barh(color={"active": "black", "death": "orange"},figsize=(13,8))
# bar plot for active and death cases
# Out:
# <AxesSubplot:ylabel='state_name'>
